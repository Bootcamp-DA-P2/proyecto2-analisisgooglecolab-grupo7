# %%
import sys

if 'google.colab' in sys.modules:

    print("Running in Google Colab")

    print(f"Python version: {sys.version}")

else:

    print("Not running in Google Colab")
# Out:
# Running in Google Colab
# Python version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]

# %% [markdown]
# # **Importar datos**

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
# La ruta estándar a la raíz de tu unidad es esta:

path = '/content/drive/MyDrive/Grupo7/kiva_loans.csv'

 

# Cargar el archivo

df = pd.read_csv(path)

 

# Ver las primeras filas

df.head()
# Out:
#        id  funded_amount  loan_amount             activity          sector  \
# 0  653051          300.0        300.0  Fruits & Vegetables            Food
# 1  653053          575.0        575.0             Rickshaw  Transportation
# 2  653068          150.0        150.0       Transportation  Transportation
# 3  653063          200.0        200.0           Embroidery            Arts
# 4  653084          400.0        400.0           Milk Sales            Food
#
#                                                  use country_code   country  \
# 0            To buy seasonal, fresh fruits to sell.            PK  Pakistan
# 1  to repair and maintain the auto rickshaw used ...           PK  Pakistan
# 2  To repair their old cycle-van and buy another ...           IN     India
# 3  to purchase an embroidery machine and a variet...           PK  Pakistan
# 4                           to purchase one buffalo.           PK  Pakistan
#
#          region currency  partner_id                posted_time  \
# 0        Lahore      PKR       247.0  2014-01-01 06:12:39+00:00
# 1        Lahore      PKR       247.0  2014-01-01 06:51:08+00:00
# 2     Maynaguri      INR       334.0  2014-01-01 09:58:07+00:00
# 3        Lahore      PKR       247.0  2014-01-01 08:03:11+00:00
# 4  Abdul Hakeem      PKR       245.0  2014-01-01 11:53:19+00:00
#
#               disbursed_time                funded_time  term_in_months  \
# 0  2013-12-17 08:00:00+00:00  2014-01-02 10:06:32+00:00            12.0
# 1  2013-12-17 08:00:00+00:00  2014-01-02 09:17:23+00:00            11.0
# 2  2013-12-17 08:00:00+00:00  2014-01-01 16:01:36+00:00            43.0
# 3  2013-12-24 08:00:00+00:00  2014-01-01 13:00:00+00:00            11.0
# 4  2013-12-17 08:00:00+00:00  2014-01-01 19:18:51+00:00            14.0
#
#    lender_count                          tags borrower_genders  \
# 0            12                           NaN           female
# 1            14                           NaN   female, female
# 2             6  user_favorite, user_favorite           female
# 3             8                           NaN           female
# 4            16                           NaN           female
#
#   repayment_interval        date
# 0          irregular  2014-01-01
# 1          irregular  2014-01-01
# 2             bullet  2014-01-01
# 3          irregular  2014-01-01
# 4            monthly  2014-01-01

# %%
import pandas as pd

df = pd.read_csv('/content/kiva_loans_42304_rows.csv')

df.head()
# Out:
#         id  funded_amount  loan_amount                   activity  \
# 0  1175609          525.0        525.0  Personal Medical Expenses
# 1  1056732          350.0        350.0               Butcher Shop
# 2   773348          225.0        225.0                       Food
# 3  1076908          325.0        325.0                    Farming
# 4   680170          500.0        500.0                    Poultry
#
#         sector                                                use  \
# 0       Health  to buy medicines for her son’s treatment at th...
# 1         Food         to buy a refrigerator for his butcher shop
# 2         Food  to buy more raw ingredients for making food sn...
# 3  Agriculture                    to purchase sacks of fertilizer
# 4  Agriculture                    To purchase more broiler chicks
#
#   country_code      country                                         region  \
# 0           TJ   Tajikistan                                      Kanibadam
# 1           MX       Mexico                                       Ecatepec
# 2           PH  Philippines  Plaridel-Unidos, Plaridel, Misamis Occidental
# 3           PH  Philippines               Pagadian City, Zamboanga del Sur
# 4           ZW     Zimbabwe                                         Nyanga
#
#   currency  partner_id                posted_time             disbursed_time  \
# 0      TJS       100.0  2016-10-27 04:54:27+00:00  2016-10-04 07:00:00+00:00
# 1      MXN       294.0  2016-04-19 15:55:26+00:00  2016-03-31 07:00:00+00:00
# 2      PHP       126.0  2014-09-23 08:53:49+00:00  2014-09-19 07:00:00+00:00
# 3      PHP       126.0  2016-05-27 08:40:46+00:00  2016-05-10 07:00:00+00:00
# 4      USD       305.0  2014-03-06 10:29:22+00:00  2014-03-05 08:00:00+00:00
#
#                  funded_time  term_in_months  lender_count  \
# 0  2016-11-05 02:14:03+00:00            14.0            18
# 1  2016-04-25 20:14:08+00:00             8.0            10
# 2  2014-10-04 14:33:45+00:00            11.0             9
# 3  2016-06-02 12:04:03+00:00             7.0             7
# 4  2014-04-02 01:31:55+00:00             8.0            11
#
#                                                 tags borrower_genders  \
# 0                             #Health and Sanitation           female
# 1  #Elderly, #First Loan, #Health and Sanitation,...             male
# 2   volunteer_pick, volunteer_like, #Woman Owned Biz           female
# 3                                      user_favorite           female
# 4          #Woman Owned Biz, #Parent, #Low-profit FP           female
#
#   repayment_interval        date
# 0            monthly  2016-10-27
# 1            monthly  2016-04-19
# 2          irregular  2014-09-23
# 3          irregular  2016-05-27
# 4          irregular  2014-03-06

# %%
df.shape
df.dtypes
df.info()
df.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42308 entries, 0 to 42307
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  42308 non-null  int64
#  1   funded_amount       42308 non-null  float64
#  2   loan_amount         42308 non-null  float64
#  3   activity            42308 non-null  object
#  4   sector              42308 non-null  object
#  5   use                 42308 non-null  object
#  6   country_code        42308 non-null  object
#  7   country             42308 non-null  object
#  8   region              42308 non-null  object
#  9   currency            42308 non-null  object
#  10  partner_id          42308 non-null  float64
#  11  posted_time         42308 non-null  object
#  12  disbursed_time      42308 non-null  object
#  13  funded_time         42308 non-null  object
#  14  term_in_months      42308 non-null  float64
#  15  lender_count        42308 non-null  int64
#  16  tags                42308 non-null  object
#  17  borrower_genders    42308 non-null  object
#  18  repayment_interval  42308 non-null  object
#  19  date                42308 non-null  object
# dtypes: float64(4), int64(2), object(14)
# memory usage: 6.5+ MB
#                   id  funded_amount   loan_amount activity       sector  \
# count   4.230800e+04   42308.000000  42308.000000    42308        42308
# unique           NaN            NaN           NaN      157           15
# top              NaN            NaN           NaN  Farming  Agriculture
# freq             NaN            NaN           NaN     4811        11861
# mean    1.024360e+06     844.327905    844.327905      NaN          NaN
# std     1.920062e+05    1081.746992   1081.746992      NaN          NaN
# min     6.531060e+05      25.000000     25.000000      NaN          NaN
# 25%     8.667138e+05     300.000000    300.000000      NaN          NaN
# 50%     1.038604e+06     500.000000    500.000000      NaN          NaN
# 75%     1.195408e+06    1000.000000   1000.000000      NaN          NaN
# max     1.338878e+06   50000.000000  50000.000000      NaN          NaN
#
#                                                       use country_code  \
# count                                               42308        42308
# unique                                              32547           74
# top     to buy a water filter to provide safe drinking...           PH
# freq                                                  432         9234
# mean                                                  NaN          NaN
# std                                                   NaN          NaN
# min                                                   NaN          NaN
# 25%                                                   NaN          NaN
# 50%                                                   NaN          NaN
# 75%                                                   NaN          NaN
# max                                                   NaN          NaN
#
#             country  region currency    partner_id                posted_time  \
# count         42308   42308    42308  42308.000000                      42308
# unique           74    4438       62           NaN                      42294
# top     Philippines  Kaduna      PHP           NaN  2014-07-04 15:10:06+00:00
# freq           9234     561     9234           NaN                          2
# mean            NaN     NaN      NaN    184.002104                        NaN
# std             NaN     NaN      NaN     99.689027                        NaN
# min             NaN     NaN      NaN      9.000000                        NaN
# 25%             NaN     NaN      NaN    126.000000                        NaN
# 50%             NaN     NaN      NaN    154.000000                        NaN
# 75%             NaN     NaN      NaN    222.000000                        NaN
# max             NaN     NaN      NaN    528.000000                        NaN
#
#                    disbursed_time                funded_time  term_in_months  \
# count                       42308                      42308    42308.000000
# unique                       1379                      40991             NaN
# top     2017-02-01 08:00:00+00:00  2016-10-08 00:20:21+00:00             NaN
# freq                          240                          6             NaN
# mean                          NaN                        NaN       14.124255
# std                           NaN                        NaN        8.434400
# min                           NaN                        NaN        2.000000
# 25%                           NaN                        NaN        8.000000
# 50%                           NaN                        NaN       14.000000
# 75%                           NaN                        NaN       14.000000
# max                           NaN                        NaN      148.000000
#
#         lender_count           tags borrower_genders repayment_interval  \
# count   42308.000000          42308            42308              42308
# unique           NaN          12447             1360                  3
# top              NaN  user_favorite           female            monthly
# freq             NaN           2418            26408              22980
# mean       23.276023            NaN              NaN                NaN
# std        28.493808            NaN              NaN                NaN
# min         1.000000            NaN              NaN                NaN
# 25%         8.000000            NaN              NaN                NaN
# 50%        15.000000            NaN              NaN                NaN
# 75%        28.000000            NaN              NaN                NaN
# max      1410.000000            NaN              NaN                NaN
#
#               date
# count        42308
# unique        1275
# top     2017-03-20
# freq           109
# mean           NaN
# std            NaN
# min            NaN
# 25%            NaN
# 50%            NaN
# 75%            NaN
# max            NaN

# %%
#Duplicados
df.duplicated().sum()
#Valores Nulos
df.isnull().sum().sort_values(ascending=False)
df['loan_amount'].describe()
# Out:
# count    671205.000000
# mean        842.397107
# std        1198.660073
# min          25.000000
# 25%         275.000000
# 50%         500.000000
# 75%        1000.000000
# max      100000.000000
# Name: loan_amount, dtype: float64

# %% [markdown]
# # **Limpieza de datos**

# %%
#Fechas
df['date'] = pd.to_datetime(df['date'], errors='coerce')
df['funded_time'] = pd.to_datetime(df['funded_time'], errors='coerce')
#Eliminar duplicados
df = df.drop_duplicates()
#Valores en blanco
# Eliminar filas sin información
df = df.dropna(subset=['loan_amount', 'country'])
# Rellenar valores en blanco
df['sector'] = df['sector'].fillna('Sin datos')
